# %%
# imports
import os
import sys
import types
import json

# figure size/format
fig_width = 10
fig_height = 5
fig_format = 'retina'
fig_dpi = 96

# matplotlib defaults / format
try:
  import matplotlib.pyplot as plt
  plt.rcParams['figure.figsize'] = (fig_width, fig_height)
  plt.rcParams['figure.dpi'] = fig_dpi
  plt.rcParams['savefig.dpi'] = fig_dpi
  from IPython.display import set_matplotlib_formats
  set_matplotlib_formats(fig_format)
except Exception:
  pass

# plotly use connected mode
try:
  import plotly.io as pio
  pio.renderers.default = "notebook_connected"
except Exception:
  pass

# enable pandas latex repr when targeting pdfs
try:
  import pandas as pd
  if fig_format == 'pdf':
    pd.set_option('display.latex.repr', True)
except Exception:
  pass



# output kernel dependencies
kernel_deps = dict()
for module in list(sys.modules.values()):
  # Some modules play games with sys.modules (e.g. email/__init__.py
  # in the standard library), and occasionally this can cause strange
  # failures in getattr.  Just ignore anything that's not an ordinary
  # module.
  if not isinstance(module, types.ModuleType):
    continue
  path = getattr(module, "__file__", None)
  if not path:
    continue
  if path.endswith(".pyc") or path.endswith(".pyo"):
    path = path[:-1]
  if not os.path.exists(path):
    continue
  kernel_deps[path] = os.stat(path).st_mtime
print(json.dumps(kernel_deps))

# set run_path if requested
if r'':
  os.chdir(r'')

# reset state
# %reset

def ojs_define(**kwargs):
  import json
  from IPython.core.display import display, HTML

  # do some minor magic for convenience when handling pandas
  # dataframes
  def convert(v):
    try:
      import pandas as pd
    except ModuleNotFoundError: # don't do the magic when pandas is not available
      return v
    if type(v) == pd.Series:
      v = pd.DataFrame(v)
    if type(v) == pd.DataFrame:
      j = json.loads(v.T.to_json(orient='split'))
      return dict((k,v) for (k,v) in zip(j["index"], j["data"]))
    else:
      return v
  
  v = dict(contents=list(dict(name=key, value=convert(value)) for (key, value) in kwargs.items()))
  display(HTML('<script type="ojs-define">' + json.dumps(v) + '</script>'), metadata=dict(ojs_define = True))
globals()["ojs_define"] = ojs_define
# Out:
# C:\Users\kerry\AppData\Local\Temp\ipykernel_21360\1140549349.py:20: DeprecationWarning:
#
# `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
# {"C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\_bootstrap.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\_bootstrap_external.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\codecs.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\aliases.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\__init__.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\utf_8.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\cp1252.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\abc.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\io.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\stat.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\_collections_abc.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\genericpath.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\ntpath.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\os.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\_sitebuiltins.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_distutils_hack\\__init__.py": 1665541945.6758869, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\types.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\warnings.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\__init__.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\_abc.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\keyword.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\operator.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\reprlib.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\collections\\__init__.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\functools.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\contextlib.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\util.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\machinery.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\win32\\lib\\pywin32_bootstrap.py": 1665545610.7738168, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\runpy.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\enum.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\sre_constants.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\sre_parse.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\sre_compile.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\copyreg.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\re.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\collections\\abc.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\typing.py": 1665532704.0, "C:\\Users\\kerry\\AppData\ ...

# %%
from sqlalchemy import create_engine
import pymssql
import pandas as pd

server = "mssql-82792-0.cloudclusters.net:16272"
username = "user"
password = "RiceOwls1912" # paste password between quote marks
database = "ghz"

string = "mssql+pymssql://" + username + ":" + password + "@" + server + "/" + database

conn = create_engine(string).connect()

data = pd.read_sql(
    """
    select ticker, date, ret, roeq, mom12m
    from data
    where date='2021-12'
    """, 
    conn
)
data = data.dropna()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2399 entries, 0 to 2406
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  2399 non-null   object
#  1   date    2399 non-null   object
#  2   ret     2399 non-null   float64
#  3   roeq    2399 non-null   float64
#  4   mom12m  2399 non-null   float64
# dtypes: float64(3), object(2)
# memory usage: 112.5+ KB

# %%
data.head(3)
# Out:
#   ticker     date       ret      roeq    mom12m
# 0   JJSF  2021-12  0.161173  0.035539  0.030303
# 1    ELA  2021-12  0.000000  0.109925 -0.054113
# 2   PLXS  2021-12  0.139648  0.027229  0.168786

# %%
data[["roeq", "mom12m", "ret"]].describe().round(3)
# Out:
#            roeq    mom12m       ret
# count  2399.000  2399.000  2399.000
# mean     -0.011     0.399     0.023
# std       1.899     0.909     0.142
# min     -83.912    -0.833    -0.580
# 25%      -0.007     0.021    -0.023
# 50%       0.028     0.256     0.036
# 75%       0.055     0.539     0.085
# max      22.041    21.256     3.338

# %%
import plotly.express as px
fig = px.scatter(
    data, 
    x="roeq", 
    y="ret", 
    trendline="ols",
    hover_data=dict(
        roeq=False,
        date=False,
        ret=False,
        mom12m=False,
        ticker=True
    ),
)

fig.update_traces(
    marker=dict(
        size=12,
        opacity=0.5
    )
)

fig.update_layout(
    template="plotly_dark",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    yaxis_tickformat=".0%",
    width=1000,
    height=420,
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="1b1ba7a5-de5e-4fc2-95ab-2649d543880b" class="plotly-graph-div" style="height:420px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b1ba7a5-de5e-4fc2-95ab-2649d543880b")) {                    Plotly.newPlot(                        "1b1ba7a5-de5e-4fc2-95ab-2649d543880b",                        [{"customdata":[["2021-12",0.0303028204001183,"JJSF"],["2021-12",-0.0541125708270501,"ELA"],["2021-12",0.1687859883649738,"PLXS"],["2021-12",1.039812655070456,"RMCF"],["2021-12",0.687573393550867,"ORCL"],["2021-12",0.5592224289430316,"MSFT"],["2021-12",0.5710011676917608,"TROW"],["2021-12",0.0856885252161314,"HON"],["2021-12",0.8435465789364642,"AMRC"],["2021-12",0.5316075492059411,"RGEN"],["2021-12",0.0077473456953258,"BWXT"],["2021-12",0.9639657443834057,"ESBK"],["2021-12",0.2803538043077456,"INDB"],["2021-12",-0.7709497173230719,"DSS"],["2021-12",0.6688596837590437,"DLHC"],["2021-12",0.8906667503838341,"CLDX"],["2021-12",0.0313640810173958,"HVT"],["2021-12",0.3173762436834619,"TMP"],["2021-12",0.483852101035567,"BCPC"],["2021-12",-0.2449411100089351,"XOMA"],["2021-12",0.2711851938309326,"DJCO"],["2021-12",-0.0751724765134499,"ASTE"],["2021-12",0.1443513743039899,"WERN"],["2021-12",0.0023293485875399,"SKYW"],["2021-12",0.2491810352425756,"FRPH"],["2021-12",-0.23208191709266,"REFR"],["2021-12",-0.2144898053987924,"AMWD"],["2021-12",0.1358475462999562,"KSPN"],["2021-12",0.3144594094339266,"ADM"],["2021-12",-0.2508055879241896,"PRG"],["2021-12",-0.0047619032861192,"VIVO"],["2021-12",1.375525667290574,"CLFD"],["2021-12",-0.3548644117817903,"PDEX"],["2021-12",0.6308701508650822,"WTS"],["2021-12",0.3747760898102945,"FNB"],["2021-12",0.0549949406630088,"LAKE"],["2021-12",1.6819957446436362,"PTSI"],["2021-12",0.0659721586985737,"CYAN"],["2021-12",-0.2000182848572824,"EHC"],["2021-12",-0.1449036472871543,"FISV"],["2021-12",0.5436520290113336,"FCNCA"],["2021-12",-0.0094538091356284,"BKTI"],["2021-12",0.2925081020937781,"BKSC"],["2021-12",-0.0859538214574865,"HTLD"],["2021-12",-0.1108333325630314,"OSUR"],["2021-12",0.9856004600711056,"CAL"],["2021-12",0.2594368770220261,"BC"],["2021-12",0.888888917494651,"DXYN"],["2021-12",0.7537722791905612,"UIS"],["2021-12",0.369076383938727,"WSFS"],["2021-12",0.148780285403298,"ITIC"],["2021-12",0.0042851076201162,"CERN"],["2021-12",0.5119423931698535,"WBS"],["2021-12",0.3484180821060407,"MKL"],["2021-12",0.0629810814044544,"AXGN"],["2021-12",0.2449508190845932,"FLIC"],["2021-12",0.7496555243122749,"FBP"],["2021-12",0.9236111347716196,"PMD"],["2021-12",0.0325841109741082,"AVD"],["2021-12",0.1207937633282389,"PLAB"],["2021-12",0.143444965375753,"CRMT"],["2021-12",0.5706673771168287,"OFG"],["2021-12",1.2242355461195409,"CATO"],["2021-12",0.5732635239199118,"FBNC"],["2021-12",0.4128148567831284,"ICCC"],["2021-12",0.2622422211366799,"WSBC"],["2021-12",0.1185762664867902,"KO"],["2021-12",0.3996951325750195,"SAFM"],["2021-12",1.4663636029757487,"AIRT"],["2021-12",0.3134229519249936,"UBSI"],["2021-12",0.0403687693191914,"ENV"],["2021-12",-0.3775100645571191,"THMO"],["2021-12",0.4488980329905301,"WASH"],["2021-12",0.4884780448948931,"CDNS"],["2021-12",0.0209450628148919,"ED"],["2021-12",0.2492517691639368,"CHCO"],["2021-12",-0.0281864359337081,"EBIX"],["2021-12",-0.0702702668028228,"CECE"],["2021-12",1.2981651923188742,"CPSH"],["2021-12",-0.1577477504326749,"FICO"],["2021-12",0.4447337110141911,"CNMD"],["2021-12",0.3743293412544224,"HBNC"],["2021-12",-0.0651938863502947,"EPAC"],["2021-12",0.2234841598449044,"ATRI"],["2021-12",0.1574905365461478,"SNFCA"],["2021-12",0.1322045842235408,"XRAY"],["2021-12",0.1888713978648017,"FAST"],["2021-12",0.7251684819407078,"CPF"],["2021-12",-0.36468549072489,"HRTX"],["2021-12",0.2638927930062174,"NAII"],["2021-12",-0.2091112857037033,"GDOT"],["2021-12 ...

# %%
import plotly.express as px
fig = px.scatter(
    data, 
    x="mom12m", 
    y="ret", 
    trendline="ols",
    hover_data=dict(
        roeq=False,
        date=False,
        ret=False,
        mom12m=False,
        ticker=True
    ),
)

fig.update_traces(
    marker=dict(
        size=12,
        opacity=0.5
    )
)

fig.update_layout(
    template="plotly_dark",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    yaxis_tickformat=".0%",
    width=1000,
    height=420,
)

fig.show()
# Out:
# <div>                            <div id="a519195f-9ab8-4f62-a2e5-77647eabe811" class="plotly-graph-div" style="height:420px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a519195f-9ab8-4f62-a2e5-77647eabe811")) {                    Plotly.newPlot(                        "a519195f-9ab8-4f62-a2e5-77647eabe811",                        [{"customdata":[[0.0355387453874538,"2021-12","JJSF"],[0.1099254569590524,"2021-12","ELA"],[0.027229099602348,"2021-12","PLXS"],[0.0305778152678194,"2021-12","RMCF"],[0.4530337078651685,"2021-12","ORCL"],[0.1223597635775621,"2021-12","MSFT"],[0.1018580954521615,"2021-12","TROW"],[0.0795062826642944,"2021-12","HON"],[0.0217140676308528,"2021-12","AMRC"],[0.0232827576634606,"2021-12","RGEN"],[0.0904351774813406,"2021-12","BWXT"],[0.0228294144466879,"2021-12","ESBK"],[0.0219031334912389,"2021-12","INDB"],[-0.0806115944922705,"2021-12","DSS"],[0.0489022464469461,"2021-12","DLHC"],[-0.0688740562199355,"2021-12","CLDX"],[0.0845609180434605,"2021-12","HVT"],[0.0322247361653537,"2021-12","TMP"],[0.0267583449873571,"2021-12","BCPC"],[-0.0273739598629466,"2021-12","XOMA"],[0.1994172947298899,"2021-12","DJCO"],[0.0128363748840086,"2021-12","ASTE"],[0.0586708804053008,"2021-12","WERN"],[0.0284177874061262,"2021-12","SKYW"],[0.0002071983747561,"2021-12","FRPH"],[-0.1087314662273476,"2021-12","REFR"],[0.0046725727707033,"2021-12","AMWD"],[-0.9509738079247816,"2021-12","KSPN"],[0.034163427858548,"2021-12","ADM"],[0.0663837231280787,"2021-12","PRG"],[0.0377060357446368,"2021-12","VIVO"],[0.0678701807497106,"2021-12","CLFD"],[0.0371422971383771,"2021-12","PDEX"],[0.0346836847946725,"2021-12","WTS"],[0.0203833936469642,"2021-12","FNB"],[0.0406937958639092,"2021-12","LAKE"],[0.094628239582368,"2021-12","PTSI"],[0.0305146411595563,"2021-12","CYAN"],[0.0686363361730409,"2021-12","EHC"],[0.0084455747072305,"2021-12","FISV"],[0.0353561345860138,"2021-12","FCNCA"],[0.0846458506032974,"2021-12","BKTI"],[0.0314852194910298,"2021-12","BKSC"],[0.028713333157996,"2021-12","HTLD"],[-0.0033800527327875,"2021-12","OSUR"],[0.0306970890949677,"2021-12","CAL"],[0.1092170948496286,"2021-12","BC"],[0.0607097325996094,"2021-12","DXYN"],[0.4246079613992762,"2021-12","UIS"],[0.0540295858957292,"2021-12","WSFS"],[0.0929286475973937,"2021-12","ITIC"],[0.0075843426814119,"2021-12","CERN"],[0.0287311544891913,"2021-12","WBS"],[0.0601726959640667,"2021-12","MKL"],[-0.0659794158925349,"2021-12","AXGN"],[0.0279034210358667,"2021-12","FLIC"],[0.0317767994865847,"2021-12","FBP"],[0.0104589447393069,"2021-12","PMD"],[0.0142870633196869,"2021-12","AVD"],[0.0129073871063467,"2021-12","PLAB"],[0.119741501318927,"2021-12","CRMT"],[0.036833411071405,"2021-12","OFG"],[0.0840290793434429,"2021-12","CATO"],[0.0333978443365079,"2021-12","FBNC"],[0.0050590219224283,"2021-12","ICCC"],[0.0253413902313462,"2021-12","WSBC"],[0.129746990911324,"2021-12","KO"],[0.0682720879870262,"2021-12","SAFM"],[0.0210564663023679,"2021-12","AIRT"],[0.0218884399512728,"2021-12","UBSI"],[-0.0090587775846395,"2021-12","ENV"],[-0.4331933575109754,"2021-12","THMO"],[0.0327212007518754,"2021-12","WASH"],[0.0613192407899208,"2021-12","CDNS"],[0.008669153575369,"2021-12","ED"],[0.032020356086947,"2021-12","CHCO"],[0.0249663325329369,"2021-12","EBIX"],[0.0014321955606825,"2021-12","CECE"],[0.0373482726423902,"2021-12","CPSH"],[0.6770979341970328,"2021-12","FICO"],[0.0183166338189285,"2021-12","CNMD"],[0.0321637299656647,"2021-12","HBNC"],[0.0662230297881712,"2021-12","EPAC"],[0.0364656324182536,"2021-12","ATRI"],[0.0414061235599629,"2021-12","SNFCA"],[0.0200933631012786,"2021-12","XRAY"],[0.0860157175153407,"2021-12","FAST"],[0.0344726589483573,"2021-12","CPF"],[-0.3109440693081921,"2021-12","HRTX"],[0.0389613806166473,"2021-12","NAII"],[0.0243607894173752,"2021-12","GDOT"],[0.00932122370936 ...

# %%
import pandas as pd

data['roeqpct'] = pd.qcut(
    data.roeq, 
    100, 
    labels=range(1, 101)
)
x = data.groupby("roeqpct").roeq.mean()
y = data.groupby("roeqpct").ret.mean()
df = pd.concat((x,y), axis=1)
df.columns = ["roeq", "ret"]
fig = px.scatter(df, x="roeq", y="ret", trendline="ols")

fig.update_traces(
    marker=dict(
        size=12,
        opacity=0.5
    )
)

fig.update_layout(
    template="plotly_dark",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    yaxis_tickformat=".0%",
    width=1000,
    height=420,
)

fig.show()
# Out:
# <div>                            <div id="f28c8152-f66b-4432-a5d8-95343482a8e9" class="plotly-graph-div" style="height:420px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f28c8152-f66b-4432-a5d8-95343482a8e9")) {                    Plotly.newPlot(                        "f28c8152-f66b-4432-a5d8-95343482a8e9",                        [{"hovertemplate":"roeq=%{x}<br>ret=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","opacity":0.5,"size":12},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-6.699004549537087,-0.6326521343931751,-0.40882831109027923,-0.29356608784354304,-0.21253005732312102,-0.18787100497824885,-0.1664299649923678,-0.14618263692595168,-0.13147049622294335,-0.11652190221750076,-0.10595084545472533,-0.09523358668905968,-0.08488673005776552,-0.07444674408237206,-0.06538457660023313,-0.057918858804083324,-0.05104049149009537,-0.044398404352733734,-0.03644389342295327,-0.029932451938780344,-0.02530215536360401,-0.0213995452948596,-0.017455057204075086,-0.01379056481156051,-0.008753609526725837,-0.005146288399098429,-0.002316587598024396,0.0001560112708973042,0.001871219679253829,0.0036349697312170123,0.005878649816656305,0.007366364897117276,0.009031791046819917,0.010469429753952162,0.01179858182357625,0.013048132062036033,0.014482286101444454,0.015852635848216834,0.016922963861437216,0.01836904792880827,0.0195387659134645,0.020458093977339234,0.021256959310648266,0.022117084444737884,0.02279720619235563,0.02360462139913005,0.0245907543562992,0.02553578059720053,0.026482290731916092,0.02719876799405604,0.027865260889091116,0.02875857391909521,0.02997202388055963,0.030715865354867224,0.031463481484806884,0.032265503854950424,0.033217770613395925,0.03393992479471575,0.03473397581944178,0.0355585312913834,0.03649478087804085,0.0376622752881633,0.03835972545085615,0.039251282513442516,0.04029728634902712,0.0412830192384206,0.04248852382806103,0.04382996587347948,0.04480234341311961,0.04598018973561124,0.04740429384764059,0.049173473618977864,0.05068431824912181,0.052165559847928894,0.05395898191774654,0.05598814536918718,0.058350170593913474,0.06120329265540892,0.0634397927904108,0.06625717907631731,0.06875261700010905,0.07132016965550714,0.07406269185792677,0.07727132987197055,0.08133559514306084,0.08545394181647621,0.09048985787873748,0.09770455621136087,0.10450573509953638,0.1122003096977559,0.12278151033360034,0.13328324924571497,0.14477415996820117,0.16206993061576902,0.19806182186829036,0.24501882559460306,0.308725033648323,0.4339066279102255,0.7734972023784955,3.6074299992322967],"xaxis":"x","y":[0.026207965546442804,-0.03277509678931284,-0.06640463198224703,-0.08458492152082424,-0.10442845926930505,-0.05231644407225152,-0.0933735207072459,0.05527639746045074,0.05139648687327283,-0.05149204809761915,-0.05191484186798335,-0.06052833655849099,-0.03915762977946238,-0.004776317994886384,-0.0953107408325498,-0.04346748095122164,-0.027538852300494906,-0.05825932894367724,0.012688351639856895,-0.020628826324051882,0.04448664320322374,0.0007031558391948529,0.009362876221227156,-0.03205992428896328,0.008526735492826754,-0.0026085141968603016,-0.004956977267283963,0.041381009825272465,0.020208662657144775,0.05770872479964356,0.021009801702651505,0.06973856658441942,0.029377583918782552,0.016985223512165245,0.04888533699947096,0.04529750975780187,0.05264261804404666,0.05270354879515554,0.03321623600398499,0.04664268546427286,0.05662435365957206,0.017124909611993627,0.04563231898646334,0.015813810071752702,0.055944441250176134,0.03869383084626555,0.03408509162545668,0.045940802180363456,0.032456337922970584,0.0592614939814666,0.04565336413519535,0.03635075712130247,0.04513472027610985,0.038089589584463575,0.04833074141060931,0.04154607294670614,0.02287519755191168,0.040403475771 ...

# %%
data['roeqpct'] = pd.qcut(
    data.roeq, 
    10, 
    labels=range(1, 11)
)
x = data.groupby("roeqpct").roeq.mean()
y = data.groupby("roeqpct").ret.mean()
df = pd.concat((x,y), axis=1)
df.columns = ["roeq", "ret"]
fig = px.scatter(df, x="roeq", y="ret", trendline="ols")

fig.update_traces(
    marker=dict(
        size=12,
    )
)

fig.update_layout(
    template="plotly_dark",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    yaxis_tickformat=".0%",
    width=1000,
    height=420,
)

fig.show()
# Out:
# <div>                            <div id="5e91aae9-8061-4a6f-a15a-a1efc37c71da" class="plotly-graph-div" style="height:420px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e91aae9-8061-4a6f-a15a-a1efc37c71da")) {                    Plotly.newPlot(                        "5e91aae9-8061-4a6f-a15a-a1efc37c71da",                        [{"hovertemplate":"roeq=%{x}<br>ret=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","size":12},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-0.8995057145524219,-0.06456365828928018,-0.008850160751657973,0.01232198831400647,0.023358032491714743,0.03186575993626061,0.04104493925682219,0.05586252079666534,0.08630968042324412,0.612954836079552],"xaxis":"x","y":[-0.035249427255863934,-0.03888940039129617,0.014275239228542576,0.04164991107827516,0.040157739013648074,0.0441110873381533,0.04678472233645149,0.046317341624914334,0.04722171324077254,0.022686781760603465],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>OLS trendline</b><br>ret = 0.0515367 * roeq + 0.0234694<br>R<sup>2</sup>=0.316574<br><br>roeq=%{x}<br>ret=%{y} <b>(trend)</b><extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","size":12},"mode":"lines","name":"","showlegend":false,"x":[-0.8995057145524219,-0.06456365828928018,-0.008850160751657973,0.01232198831400647,0.023358032491714743,0.03186575993626061,0.04104493925682219,0.05586252079666534,0.08630968042324412,0.612954836079552],"xaxis":"x","y":[-0.022888210034649636,0.020141961946829844,0.023013252670240306,0.024104395712657534,0.02467315719185212,0.02511161752854761,0.02558468229016757,0.02634833178802937,0.027917478419524883,0.0550590404610013],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#4 ...

# %%
data['mom12mpct'] = pd.qcut(
    data.mom12m, 
    100, 
    labels=range(1, 101)
)
x = data.groupby("mom12mpct").mom12m.mean()
y = data.groupby("mom12mpct").ret.mean()
df = pd.concat((x,y), axis=1)
df.columns = ["mom12m", "ret"]
fig = px.scatter(df, x="mom12m", y="ret", trendline="ols")

fig.update_traces(
    marker=dict(
        size=12,
        opacity=0.5
    )
)

fig.update_layout(
    template="plotly_dark",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    yaxis_tickformat=".0%",
    width=1000,
    height=420,
)

fig.show()
# Out:
# <div>                            <div id="3c526e33-0caa-4632-90b6-7e838ba9eea6" class="plotly-graph-div" style="height:420px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c526e33-0caa-4632-90b6-7e838ba9eea6")) {                    Plotly.newPlot(                        "3c526e33-0caa-4632-90b6-7e838ba9eea6",                        [{"hovertemplate":"mom12m=%{x}<br>ret=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","opacity":0.5,"size":12},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-0.7233105012082227,-0.5818922178704616,-0.4942018250860308,-0.42644891606560514,-0.3794966944758343,-0.34632883970768075,-0.2994990776246742,-0.26811228217618793,-0.23472991058556814,-0.2061181606378488,-0.18312956547708495,-0.16147273267756565,-0.1390114151658284,-0.11881341552899392,-0.10236653955351806,-0.08767680425929213,-0.07476018186343165,-0.06091594543546127,-0.0482771929742311,-0.03160393018306986,-0.021889491221209156,-0.012371189442703217,0.0015516909336271833,0.009710740088159737,0.017844847244544344,0.02640862166926998,0.03460216885979756,0.04459101487224897,0.05638770952736033,0.06739150400391404,0.080516011598514,0.09283609016932241,0.10439329045805958,0.10978869181131405,0.11772279866494428,0.12316270968806751,0.13198495642950978,0.14074688816048594,0.14864912023875895,0.1570861674089347,0.16627412501588537,0.17832194718670533,0.18992452737094623,0.19911416394265802,0.20933013275602272,0.2180736598738826,0.2285566319446065,0.23793643276948392,0.24565994378034503,0.25286801223870375,0.25872970017673624,0.264510362665116,0.27213955470894674,0.2806218408063185,0.28910792088701515,0.29738962500210436,0.30740417177951207,0.3176779454908006,0.33025156481721263,0.3414459896170387,0.35352808980310724,0.36507918858848126,0.3746848369941351,0.38873403070133405,0.4016419048715017,0.4133787287545556,0.42702154830393635,0.4389144846326878,0.4502046248054706,0.46216928095800086,0.47585979878380963,0.48491153051056823,0.49889587966318727,0.5180005122384558,0.5321236481977587,0.5466553296974263,0.5595149896095354,0.5734061464759933,0.5857558173458509,0.6060394762082386,0.6318001190965911,0.6519124664722036,0.6750791258770118,0.6976839934617916,0.7281259233697738,0.7648047033264677,0.801463987717641,0.8522506284123015,0.9026075144358673,0.9358485541549003,0.999189245764545,1.0593284469153488,1.1410470311134842,1.2682480226510016,1.3963570540464822,1.5814184926774832,1.7903403230953208,2.3424786361981633,3.1985587398296675,6.4839628741051385],"xaxis":"x","y":[-0.1548418258316815,-0.10834273341849134,-0.08922350072922804,-0.021381039870902896,-0.004403243083894869,-0.05385877021277943,-0.024996189187125595,-0.05163557062041944,0.002985395762758946,0.004115362506126977,0.018351938788934288,0.054608842193071404,-0.0055280902791613185,0.031072743198213473,-0.04063075330729287,-0.001836853703328727,0.008857672025139122,0.05058365039682635,0.04673424991779027,0.01815747259145911,0.15777606217307036,0.07394728184832879,0.046606124737688,0.043261667257562884,0.035294945545805,0.06595655912921451,0.03991297781855487,0.03406028439834091,0.03783379204105582,0.007161259825807067,0.06394452136009927,0.05318248237502604,0.046197908852870236,0.04516014650774497,0.07846357035062583,0.06030796642880885,0.025642562968035517,0.04369825505030649,0.03003616991918533,0.04910814979424077,0.041305263934191296,0.048948760687684,0.053086786686132335,0.03659879311453548,0.033309918124966,0.03764850339697051,0.04678330648069578,0.024725862778723226,0.06703748654884593,0.051291144196208394,0.05795836110558843,0.04095299350835071,0.026602673669306864,0.053385944066879604,0.04345290359924545,0.022258440808703484,0.022321697178995206,0.056896961604555436,0.042518291738815585,0.032428331731352934,0.05195540387649086,0.0099406 ...

# %%
data['mom12mpct'] = pd.qcut(
    data.mom12m, 
    10, 
    labels=range(1, 11)
)
x = data.groupby("mom12mpct").mom12m.mean()
y = data.groupby("mom12mpct").ret.mean()
df = pd.concat((x,y), axis=1)
df.columns = ["mom12m", "ret"]
fig = px.scatter(df, x="mom12m", y="ret", trendline="ols")

fig.update_traces(
    marker=dict(
        size=12,
        opacity=0.5
    )
)

fig.update_layout(
    template="plotly_dark",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    yaxis_tickformat=".0%",
    width=1000,
    height=420,
)

fig.show()
# Out:
# <div>                            <div id="c9db1e9a-7daf-48ec-bfe1-d804879d0943" class="plotly-graph-div" style="height:420px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9db1e9a-7daf-48ec-bfe1-d804879d0943")) {                    Plotly.newPlot(                        "c9db1e9a-7daf-48ec-bfe1-d804879d0943",                        [{"hovertemplate":"mom12m=%{x}<br>ret=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","opacity":0.5,"size":12},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-0.39601384254381145,-0.1008027723118477,0.02242276165350098,0.12068867246279112,0.21260595768792395,0.29608350846293924,0.40753567184132106,0.5381163128730825,0.7641577016324549,2.1260928866396633],"xaxis":"x","y":[-0.05015821146856372,0.01803708718216511,0.05418109547754282,0.049574173360694335,0.04407358259489529,0.03980200843170486,0.03717716364644728,0.028226242257126898,0.029755412307955927,-0.021620800311211493],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>OLS trendline</b><br>ret = -0.00885139 * mom12m + 0.0264373<br>R<sup>2</sup>=0.033394<br><br>mom12m=%{x}<br>ret=%{y} <b>(trend)</b><extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","opacity":0.5,"size":12},"mode":"lines","name":"","showlegend":false,"x":[-0.39601384254381145,-0.1008027723118477,0.02242276165350098,0.12068867246279112,0.21260595768792395,0.29608350846293924,0.40753567184132106,0.5381163128730825,0.7641577016324549,2.1260928866396633],"xaxis":"x","y":[0.029942534126990644,0.027329507219076548,0.026238790547304953,0.02536900111537883,0.024555405814203433,0.02381651385391724,0.022830007820711522,0.021674188262859048,0.01967340885216011,0.007618395866154978],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d ...
