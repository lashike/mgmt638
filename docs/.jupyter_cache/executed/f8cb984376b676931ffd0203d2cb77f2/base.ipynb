# %%
# imports
import os
import sys
import types
import json

# figure size/format
fig_width = 10
fig_height = 5
fig_format = 'retina'
fig_dpi = 96

# matplotlib defaults / format
try:
  import matplotlib.pyplot as plt
  plt.rcParams['figure.figsize'] = (fig_width, fig_height)
  plt.rcParams['figure.dpi'] = fig_dpi
  plt.rcParams['savefig.dpi'] = fig_dpi
  from IPython.display import set_matplotlib_formats
  set_matplotlib_formats(fig_format)
except Exception:
  pass

# plotly use connected mode
try:
  import plotly.io as pio
  pio.renderers.default = "notebook_connected"
except Exception:
  pass

# enable pandas latex repr when targeting pdfs
try:
  import pandas as pd
  if fig_format == 'pdf':
    pd.set_option('display.latex.repr', True)
except Exception:
  pass



# output kernel dependencies
kernel_deps = dict()
for module in list(sys.modules.values()):
  # Some modules play games with sys.modules (e.g. email/__init__.py
  # in the standard library), and occasionally this can cause strange
  # failures in getattr.  Just ignore anything that's not an ordinary
  # module.
  if not isinstance(module, types.ModuleType):
    continue
  path = getattr(module, "__file__", None)
  if not path:
    continue
  if path.endswith(".pyc") or path.endswith(".pyo"):
    path = path[:-1]
  if not os.path.exists(path):
    continue
  kernel_deps[path] = os.stat(path).st_mtime
print(json.dumps(kernel_deps))

# set run_path if requested
if r'':
  os.chdir(r'')

# reset state
# %reset

def ojs_define(**kwargs):
  import json
  from IPython.core.display import display, HTML

  # do some minor magic for convenience when handling pandas
  # dataframes
  def convert(v):
    try:
      import pandas as pd
    except ModuleNotFoundError: # don't do the magic when pandas is not available
      return v
    if type(v) == pd.Series:
      v = pd.DataFrame(v)
    if type(v) == pd.DataFrame:
      j = json.loads(v.T.to_json(orient='split'))
      return dict((k,v) for (k,v) in zip(j["index"], j["data"]))
    else:
      return v
  
  v = dict(contents=list(dict(name=key, value=convert(value)) for (key, value) in kwargs.items()))
  display(HTML('<script type="ojs-define">' + json.dumps(v) + '</script>'), metadata=dict(ojs_define = True))
globals()["ojs_define"] = ojs_define
# Out:
# C:\Users\kerry\AppData\Local\Temp\ipykernel_19504\1140549349.py:20: DeprecationWarning:
#
# `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
# {"C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\_bootstrap.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\_bootstrap_external.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\codecs.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\aliases.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\__init__.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\utf_8.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\cp1252.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\abc.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\io.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\stat.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\_collections_abc.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\genericpath.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\ntpath.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\os.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\_sitebuiltins.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_distutils_hack\\__init__.py": 1665541945.6758869, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\types.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\warnings.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\__init__.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\_abc.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\keyword.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\operator.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\reprlib.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\collections\\__init__.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\functools.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\contextlib.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\util.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\machinery.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\win32\\lib\\pywin32_bootstrap.py": 1665545610.7738168, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\runpy.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\enum.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\sre_constants.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\sre_parse.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\sre_compile.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\copyreg.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\re.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\collections\\abc.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\typing.py": 1665532704.0, "C:\\Users\\kerry\\AppData\ ...

# %%
from sqlalchemy import create_engine
import pymssql
import pandas as pd

server = "mssql-82792-0.cloudclusters.net:16272"
username = "user"
password = "RiceOwls1912" # paste password between quote marks
database = "ghz"

string = "mssql+pymssql://" + username + ":" + password + "@" + server + "/" + database

conn = create_engine(string).connect()

data = pd.read_sql(
    """
    select ticker, date, ret, roeq, mom12m
    from data
    where date='2021-01'
    """, 
    conn
)
data = data.dropna()
data['rnk'] = data.ret.rank(pct=True)

from sklearn.preprocessing import QuantileTransformer
transform = QuantileTransformer(
    output_distribution="normal"
)

old = data.roeq.to_numpy().reshape(-1,1)
new = transform.fit_transform(old)

from sklearn.neural_network import MLPRegressor

X = data[["roeq", "mom12m"]]
y = data["rnk"]

model = MLPRegressor(
  hidden_layer_sizes=(4, 2),
  random_state=0
)

# %%
import plotly.graph_objects as go
import numpy as np

old = np.ravel(old)
new = np.ravel(new)

trace1 = go.Box(
    y=old,
    name="old",
)

fig = go.Figure(trace1)

fig.update_layout(
    template="plotly_dark",
   
    width=1000,
    height=500,
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="7a824316-d742-4532-8f2e-e110bb9aa277" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a824316-d742-4532-8f2e-e110bb9aa277")) {                    Plotly.newPlot(                        "7a824316-d742-4532-8f2e-e110bb9aa277",                        [{"name":"old","y":[-0.0151812337048116,0.0457632600258732,0.0401564940317604,-0.1894502996486877,0.2188970846505093,0.0978332066968847,0.0937208579421821,0.0612672863296304,0.0101000284605612,0.0148267178184224,0.149606995846449,0.0154083466115198,0.0372221112504625,0.0148256547769305,-0.0399723852260959,0.0429985626657489,-0.1317873911329343,0.0540311431706457,0.0314628284687874,0.0275685756083683,-0.0859213502273888,0.1493346166722464,0.0151224348786268,0.0355088218533695,-0.011886173766015,0.0111364612411423,-0.0620432281138236,0.0229238099860393,-1.5268026565464896,0.0247467285774588,0.040782821125746,0.1344868554218634,0.0392792036616873,0.148318666588962,0.0208720810084728,0.017267657992565,0.0998396407953816,-0.0062040631713844,0.0087088224157516,0.0231317958307362,6.280815249819426e-05,0.0388591845398128,-0.0262452638388318,0.0286308320299088,0.0280156801346014,-0.0361672502688246,-0.1088113186159208,0.0546137915164531,-0.1040677087831419,0.3126277073968124,-0.0038760619515816,0.0789285967099925,0.0348809848310117,0.0171821494886161,0.0948249966463417,-0.0652608016490329,0.0285984652148141,0.00966291184775,-
301811199296925,-0.546703530423891,0.48669186837858397,0.47057993654656877,-0.632301778788112,-1.0015810174453927,0.9667404586041071,-0.9804313761207489,1.8270042019048216,-0.2863481792314014,1.2104667197915342,0.6481264870457863,0.14524095668271506,1.3116583036881952,-0.8105981776541225,0.48591247267648213,-0.0666458886155926,-1.0774678536616789,-0.01658626819538472,0.05043213115916413,1.1023318740447008,0.2642885041938869,-0.5492128464593481,0.19411668597464682,-0.5496669503585896,-0.20352772520860685,1.3280002726149744,0.3560167913912075,0.5133575412220885,-0.6191701273265416,0.10050905354218102,-0.30702654127609635,-5.199337582605575,0.7845425310628663,1.0539923179868698,-0.04699755091144722,-0.4283475485165774,0.4315906374654715,0.844681325675064,0.1305126838173216,0.9145393914535759,1.811894261310474,-0.6560666842969227,0.33504011182980903,-0.4176719123501952,0.6948554056845371,1.3775792014418573,-0.49502758835108657,1.2691966857755876,0.1834345602246664,-1.1549919758837448,0.400887230400799,-0.1801718735759259,-0.03141719142534293,0.7749128322515466,1.2640167453327624,0.8981970141327091,0.9083616814099688,0.4006210202803752,0.7020901558811162,0.6061385554385688,-0.04167728849116299,-0.013725554237702754,0.36177618612402607,0.4602717195676394,0.5792200878046172,-0.31001551615183665,-0.3272464791881712,-0.9734680352078712,1.4615256753645665,0.8514758680951697,1.3860516493365143,0.8367849655902072,-0.8866156887701538,5.19933758270342,0.2310275351339647,-0.2063154336368209,0.8848985059215159,-0.5658255765310352,0.6030984158453809,0.17453394900232944,-0.016307400802815602,0.8405236952726306,-0.07035931480034852,0.05359628954779606,-0.05706216396773917,1.1073172807960738,0.30711330511771906,0.6862736516092541,0.6758860442635131,1.4101996512075932,2.1219941583337483,0.410316868204177,-0.44577075906015184,2.0282977486021636,-1.6835730882388453,0.41805532309022275,1.5632150956987017,-0.4730924004075014,-0.3606265917501048,-0.8241065040804367,-0.02564465407317782,1.3522698421825534,-1.0440777156410241,-0.1549763183892837,0.3828415660653737,0.9967468660083735,1.6496027586305226,0.370888529397005,1.0433626846273132,0.34318281792078675,0.2497179442089176,-1.3401991900202277,1.130643057176958,-0.2233717089669175,-1.4529670491319768,0.49450481174621314,-0.056622957247592046,-0.06844952587835668,0.5364596024992395,0.23636146886087642,-2.0640927215838696,-0.47863724822721165,0.6365439076985071,0.33036286729674574,1.4341545132703275,-0.933944262123294,-0.9373442480622659,-0.48103112601670955,0.2019339038367084,2.187061565399166,0.9511076287606468,0.8111847656390024,-1.6550651803486887,0.5820813197375321,-1.836601 ...

# %%
import numpy as np
from scipy.stats import gaussian_kde as kde

old = np.ravel(old)
new = np.ravel(new)
density_old = kde(old)
density_new = kde(new)
mn = max(np.min(old), np.min(new))
mx = min(np.max(old), np.max(new))
grid = np.linspace(mn, mx, 100)

trace1 = go.Scatter(
  x=grid,
  y=density_old(grid),
  mode="lines",
  name="old"
)

trace2 = go.Scatter(
  x=grid, 
  y=density_new(grid),
  mode="lines", 
  name="new"
)
fig = go.Figure()
fig.add_trace(trace1)
fig.add_trace(trace2)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="Annual Return",
    yaxis_title="",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    xaxis_tickformat=".0%",
    yaxis_tickformat="",
    width=1000,
    height=360,
     legend=dict(
        yanchor="top", 
        y=0.99, 
        xanchor="left", 
        x=0.01
    ),
)

fig.show()
# Out:
# <div>                            <div id="3db58004-d822-4e3c-8a3f-39abde785415" class="plotly-graph-div" style="height:360px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("